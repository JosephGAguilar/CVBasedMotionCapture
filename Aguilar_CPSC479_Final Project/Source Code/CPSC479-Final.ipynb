# %% [markdown]
# # CPSC 479/579 Final: Video-Based Motion Capture #

# %% [markdown]
# ## Setup
#
# In the cells below, we install necessary packages, set up imports and define the data paths.

# %%
import sys
import os
import os.path as osp
import argparse
import numpy as np
import cv2
import math
import torch
import torchvision.transforms as transforms
from torch.nn.parallel.data_parallel import DataParallel
import torch.backends.cudnn as cudnn

sys.path.append('main/')
from PoseConfig import p_cfg
from RootConfig import r_cfg
from PoseModel import get_pose_net
from RootModel import get_root_net
from PoseDataset import p_generate_patch_image
from RootDataset import r_generate_patch_image
sys.path.append('common/')
from utils.PoseUtils import p_process_bbox, p_pixel2cam
from utils.PoseVis import p_vis_keypoints, p_vis_3d_multiple_skeleton
from utils.RootUtils import r_process_bbox, r_pixel2cam
from utils.RootVis import r_vis_keypoints, r_vis_3d_skeleton

# %%
# Consolidate overlapping bounding boxes
def consolidate_bounding_boxes(boxes, threshold=0.5):
    def iou(box1, box2):
        # Calculate intersection over union (IoU) between two boxes
        x1 = max(box1[0], box2[0])
        y1 = max(box1[1], box2[1])
        x2 = min(box1[0] + box1[2], box2[0] + box2[2])
        y2 = min(box1[1] + box1[3], box2[1] + box2[3])
        intersection = max(0, x2 - x1) * max(0, y2 - y1)
        area1 = box1[2] * box1[3]
        area2 = box2[2] * box2[3]
        union = area1 + area2 - intersection
        return intersection / union if union > 0 else 0

    consolidated = []
    while boxes:
        box = boxes.pop(0)
        to_merge = [box]
        for other_box in boxes[:]:
            if iou(box, other_box) > threshold:
                to_merge.append(other_box)
                boxes.remove(other_box)
        # Merge boxes by calculating the bounding box of best fit
        x_coords = [b[0] for b in to_merge] + [b[0] + b[2] for b in to_merge]
        y_coords = [b[1] for b in to_merge] + [b[1] + b[3] for b in to_merge]
        x_min, y_min = min(x_coords), min(y_coords)
        x_max, y_max = max(x_coords), max(y_coords)
        consolidated.append((x_min, y_min, x_max - x_min, y_max - y_min))
    return consolidated

# Load YOLO model
def bbox_extractor(image):
    net = cv2.dnn.readNet("yolov3.weights", "yolov3.cfg")


# Get image dimensions
    (height, width) = image.shape[:2]

# Define the neural network input
    blob = cv2.dnn.blobFromImage(image, 1 / 255.0, (416, 416), swapRB=True, crop=False)
    net.setInput(blob)

# Perform forward propagation
    output_layer_name = net.getUnconnectedOutLayersNames()
    output_layers = net.forward(output_layer_name)

# Initialize list of detected people
    people = []

# Loop over the output layers
    for output in output_layers:
    # Loop over the detections
        for detection in output:
        # Extract the class ID and confidence of the current detection
            scores = detection[5:]
            class_id = np.argmax(scores)
            confidence = scores[class_id]

        # Only keep detections with a high confidence
            if class_id == 0 and confidence > 0.5:
            # Object detected
                center_x = int(detection[0] * width)
                center_y = int(detection[1] * height)
                w = int(detection[2] * width)
                h = int(detection[3] * height)

            # Rectangle coordinates
                x = int(center_x - w / 2)
                y = int(center_y - h / 2)

            # Add the detection to the list of people
                people.append((x, y, w, h))
    people = consolidate_bounding_boxes(people)
    return people

image = cv2.imread("input.jpg")
people = bbox_extractor(image)
print(people)
# Draw bounding boxes around the people
for (x, y, w, h) in people:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)

# Save the image with bounding boxes
cv2.imwrite("output_with_bounding_boxes.jpg", image)
# Out:
# [(133, -37, 824, 1696), (-8, 413, 385, 961)]
# True

# %%
def extract_root_depth_from_image(original_img, vis = False):
    r_cfg.set_args('n')
    cudnn.benchmark = True

# snapshot load
    model_path = './snapshot_RootNet.pth.tar'
    assert osp.exists(model_path), 'Cannot find model at ' + model_path
    model = get_root_net(r_cfg, False)
    model = DataParallel(model)
    ckpt = torch.load(model_path,  map_location=torch.device('cpu'))
    model.load_state_dict(ckpt['network'])
    model.eval()

# prepare input image
    transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize(mean=r_cfg.pixel_mean, std=r_cfg.pixel_std)])
    original_img_height, original_img_width = original_img.shape[:2]

# prepare bbox for each human
    bbox_list = bbox_extractor(original_img)
    person_num = len(bbox_list)
    #print(person_num)

# normalized camera intrinsics
    focal = [1500, 1500] # x-axis, y-axis
    princpt = [original_img_width/2, original_img_height/2] # x-axis, y-axis
    #print('focal length: (' + str(focal[0]) + ', ' + str(focal[1]) + ')')
    #print('principal points: (' + str(princpt[0]) + ', ' + str(princpt[1]) + ')')

    roots = []
# for cropped and resized human image, forward it to RootNet
    for n in range(person_num):
        bbox = r_process_bbox(np.array(bbox_list[n]), original_img_width, original_img_height)
        img, img2bb_trans = r_generate_patch_image(original_img, bbox, False, 0.0) 
        img = transform(img)[None,:,:,:]
        k_value = np.array([math.sqrt(r_cfg.bbox_real[0]*r_cfg.bbox_real[1]*focal[0]*focal[1]/(bbox[2]*bbox[3]))]).astype(np.float32)
        k_value = torch.FloatTensor([k_value])[None,:]

    # forward
        with torch.no_grad():
            root_3d = model(img, k_value) # x,y: pixel, z: root-relative depth (mm)
        img = img[0].cpu().numpy()
        root_3d = root_3d[0].cpu().numpy()

    # save output in 2D space (x,y: pixel)
        if vis:
            vis_img = img.copy()
            vis_img = vis_img * np.array(r_cfg.pixel_std).reshape(3,1,1) + np.array(r_cfg.pixel_mean).reshape(3,1,1)
            vis_img = vis_img.astype(np.uint8)
            vis_img = vis_img[::-1, :, :]
            vis_img = np.transpose(vis_img,(1,2,0)).copy()
            vis_root = np.zeros((2))
            vis_root[0] = root_3d[0] / r_cfg.output_shape[1] * r_cfg.input_shape[1]
            vis_root[1] = root_3d[1] / r_cfg.output_shape[0] * r_cfg.input_shape[0]
            cv2.circle(vis_img, (int(vis_root[0]), int(vis_root[1])), radius=5, color=(0,255,0), thickness=-1, lineType=cv2.LINE_AA)
            cv2.imwrite('output_root_2d_' + str(n) + '.jpg', vis_img)
    
        print('Root joint depth: ' + str(root_3d[2]) + ' mm')
        roots.append(root_3d[2])
    return roots

img_path = 'input.jpg'
original_img = cv2.imread(img_path)
extract_root_depth_from_image(original_img, True)
# Out:
# >>> Using CPU
# Root joint depth: 1932.1128 mm
# Root joint depth: 2763.571 mm
# [1932.1128, 2763.571]

# %%
def extract_pose(original_img, vis = False):
    p_cfg.set_args('n')
    cudnn.benchmark = True

# MuCo joint set
    joint_num = 21
    joints_name = ('Head_top', 'Thorax', 'R_Shoulder', 'R_Elbow', 'R_Wrist', 'L_Shoulder', 'L_Elbow', 'L_Wrist', 'R_Hip', 'R_Knee', 'R_Ankle', 'L_Hip', 'L_Knee', 'L_Ankle', 'Pelvis', 'Spine', 'Head', 'R_Hand', 'L_Hand', 'R_Toe', 'L_Toe')
    flip_pairs = ( (2, 5), (3, 6), (4, 7), (8, 11), (9, 12), (10, 13), (17, 18), (19, 20) )
    skeleton = ( (0, 16), (16, 1), (1, 15), (15, 14), (14, 8), (14, 11), (8, 9), (9, 10), (10, 19), (11, 12), (12, 13), (13, 20), (1, 2), (2, 3), (3, 4), (4, 17), (1, 5), (5, 6), (6, 7), (7, 18) )

# snapshot load
    model_path = './snapshot_PoseNet.pth.tar'
    assert osp.exists(model_path), 'Cannot find model at ' + model_path
    model = get_pose_net(p_cfg, False, joint_num)
    model = DataParallel(model)
    ckpt = torch.load(model_path, map_location=torch.device('cpu'))
    model.load_state_dict(ckpt['network'])
    model.eval()

# prepare input image
    transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize(mean=p_cfg.pixel_mean, std=p_cfg.pixel_std)])
    original_img_height, original_img_width = original_img.shape[:2]

# prepare bbox
    bbox_list = bbox_extractor(original_img)
    root_depth_list = extract_root_depth_from_image(original_img) # obtain this from RootNet (https://github.com/mks0601/3DMPPE_ROOTNET_RELEASE/tree/master/demo)
    assert len(bbox_list) == len(root_depth_list)
    person_num = len(bbox_list)

# normalized camera intrinsics
    focal = [1500, 1500] # x-axis, y-axis
    princpt = [original_img_width/2, original_img_height/2] # x-axis, y-axis
    #print('focal length: (' + str(focal[0]) + ', ' + str(focal[1]) + ')')
    #print('principal points: (' + str(princpt[0]) + ', ' + str(princpt[1]) + ')')

# for each cropped and resized human image, forward it to PoseNet
    output_pose_2d_list = []
    output_pose_3d_list = []
    for n in range(person_num):
        bbox = p_process_bbox(np.array(bbox_list[n]), original_img_width, original_img_height)
        img, img2bb_trans = p_generate_patch_image(original_img, bbox, False, 1.0, 0.0, False) 
        img = transform(img)[None,:,:,:]

    # forward
        with torch.no_grad():
            pose_3d = model(img) # x,y: pixel, z: root-relative depth (mm)

    # inverse affine transform (restore the crop and resize)
        pose_3d = pose_3d[0].cpu().numpy()
        pose_3d[:,0] = pose_3d[:,0] / p_cfg.output_shape[1] * p_cfg.input_shape[1]
        pose_3d[:,1] = pose_3d[:,1] / p_cfg.output_shape[0] * p_cfg.input_shape[0]
        pose_3d_xy1 = np.concatenate((pose_3d[:,:2], np.ones_like(pose_3d[:,:1])),1)
        img2bb_trans_001 = np.concatenate((img2bb_trans, np.array([0,0,1]).reshape(1,3)))
        pose_3d[:,:2] = np.dot(np.linalg.inv(img2bb_trans_001), pose_3d_xy1.transpose(1,0)).transpose(1,0)[:,:2]
        output_pose_2d_list.append(pose_3d[:,:2].copy())
    
    # root-relative discretized depth -> absolute continuous depth
        pose_3d[:,2] = (pose_3d[:,2] / p_cfg.depth_dim * 2 - 1) * (p_cfg.bbox_3d_shape[0]/2) + root_depth_list[n]
        pose_3d = p_pixel2cam(pose_3d, focal, princpt)
        output_pose_3d_list.append(pose_3d.copy())

# visualize 2d poses
    if vis:
        vis_img = original_img.copy()
        for n in range(person_num):
            vis_kps = np.zeros((3,joint_num))
            vis_kps[0,:] = output_pose_2d_list[n][:,0]
            vis_kps[1,:] = output_pose_2d_list[n][:,1]
            vis_kps[2,:] = 1
            vis_img = p_vis_keypoints(vis_img, vis_kps, skeleton)
        cv2.imwrite('output_pose_2d.jpg', vis_img)

    # visualize 3d poses
        vis_kps = np.array(output_pose_3d_list)
        p_vis_3d_multiple_skeleton(vis_kps, np.ones_like(vis_kps), skeleton, 'output_pose_3d (x,y,z: camera-centered. mm.)')
    
    return output_pose_2d_list, output_pose_3d_list

img_path = 'input.jpg'
original_img = cv2.imread(img_path)
output_pose_2d_list, output_pose_3d_list = extract_pose(original_img, True)
# Out:
# >>> Using CPU
# >>> Using CPU
# Root joint depth: 1932.1128 mm
# Root joint depth: 2763.571 mm
# /Users/josephaguilar/Documents/Final/main/../common/utils/PoseVis.py:101: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter(kpt_3d[n, i1, 0], kpt_3d[n, i1, 2], -kpt_3d[n, i1, 1], c=colors[l], marker='o')
# /Users/josephaguilar/Documents/Final/main/../common/utils/PoseVis.py:103: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter(kpt_3d[n, i2, 0], kpt_3d[n, i2, 2], -kpt_3d[n, i2, 1], c=colors[l], marker='o')

# %%
import cv2

def process_video(input_video_path, output_video_path):
    # Open the input video
    cap = cv2.VideoCapture(input_video_path)
    length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print( length )
    if not cap.isOpened():
        print("Error: Could not open video.")
        return

    # Get video properties
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')

    # Create a VideoWriter object for the output video
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Apply pose extraction and visualization
        _, _ = extract_pose(frame, vis=True)

        # Load the frame with the pose skeleton applied
        vis_frame = cv2.imread('output_pose_2d.jpg')

        # Write the processed frame to the output video
        out.write(vis_frame)

    # Release resources
    cap.release()
    out.release()
    print(f"Processed video saved to {output_video_path}")

# Example usage
process_video('input_video.mp4', 'output_video.mp4')
# Out:
# 460
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 4922.419 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 4921.6626 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 4742.263 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 4815.551 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 4718.9663 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 5068.503 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 4761.8237 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 4853.513 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 4733.107 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 4779.5317 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 4870.4897 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 4811.791 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 4790.3535 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 4764.8926 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 4587.2515 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 4585.559 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 4595.7666 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 4495.0376 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 4400.8384 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 4638.3057 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 4681.706 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 4626.1494 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 4469.375 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 4299.0127 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 3830.287 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 3647.9578 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 3298.4277 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 3038.4402 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2913.8975 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2777.0752 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2673.6597 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2597.2402 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2555.2224 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2353.3967 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2324.0623 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2334.9597 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2420.265 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2487.606 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2536.21 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2348.0757 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1882.7881 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1722.8379 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1830.0483 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1655.2054 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1805.043 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1910.7471 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2133.9795 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2032.4094 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2092.0205 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2265.344 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2277.8467 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2026.2028 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2097.0564 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2071.0579 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1897.8727 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2118.4956 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1900.397 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1846.8036 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1875.7883 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1876.3981 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1817.3998 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1928.3738 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2035.1777 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2033.0984 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1865.1007 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1766.3906 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1796.8982 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2231.6934 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1899.7776 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1972.7797 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2010.4176 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2017.0557 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2105.9062 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2018.8574 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1948.8882 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1814.523 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1918.3473 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1831.9392 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1951.9893 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1926.0262 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1883.5824 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1926.0032 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2041.3052 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2023.2655 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1911.2194 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1874.4877 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1849.2786 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2012.0576 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1974.9751 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1947.3145 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1915.7913 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2009.9491 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2054.5676 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1864.0614 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1896.8193 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1948.0308 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2000.4865 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1935.987 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1869.2203 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1897.445 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1881.1857 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2013.1918 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2048.4111 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2128.3906 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2088.435 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2003.8993 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2027.732 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2036.1385 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2052.5085 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2074.0706 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2063.5886 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2089.919 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2107.1753 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2031.6392 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1991.6926 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1932.2273 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2025.8662 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2089.204 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2090.999 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2094.735 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2087.919 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2012.8545 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2018.7037 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1843.8141 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1992.9058 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1984.1736 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1948.4459 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1942.0338 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1897.4667 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1965.5723 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1954.9987 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1972.2905 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1988.4323 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2000.4066 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1965.3285 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1940.9917 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1801.0776 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1943.4115 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1890.3175 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2017.424 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1998.1787 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2041.7238 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2006.8743 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1972.7151 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2036.3738 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1854.9373 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1952.7471 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1817.0212 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1876.6682 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1782.0155 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1873.0409 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1850.5283 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1812.0244 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1832.2543 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1781.932 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1839.268 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1813.3351 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1789.6116 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1765.8308 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1809.7356 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1781.6125 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1850.2606 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1924.3444 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1723.6179 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1839.1606 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1837.1124 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1868.7281 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1795.1398 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1832.1481 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1836.7697 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1699.077 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1771.9348 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1868.5862 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1834.8352 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1963.3225 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1786.9286 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1800.8917 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1771.4185 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1732.9458 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1789.0707 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1904.2477 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1774.1088 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1789.1354 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1824.4562 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1761.5618 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1711.4375 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1808.3871 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1845.7244 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1767.1794 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1921.9911 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1964.7772 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1859.7965 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1920.0511 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1923.6489 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1781.2142 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1891.7289 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1895.9401 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1917.2267 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1921.0964 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1877.0134 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1919.1775 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2014.1908 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1962.8884 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1867.8376 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1963.7714 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1953.3464 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2032.5746 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1983.9958 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1968.5176 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2002.2144 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1985.3229 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1941.6985 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1968.3134 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2100.6433 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2161.12 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2022.1295 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1941.2058 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1999.2399 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2100.9321 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2106.4473 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2122.689 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2090.803 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2155.9556 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2144.3518 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2103.505 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2085.9673 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2121.429 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2121.7117 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1966.4977 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2030.7566 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1965.2626 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1930.5176 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1767.3652 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1980.7769 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1841.2472 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1854.2029 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1833.6943 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1955.0363 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1729.3938 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1702.3376 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1885.3536 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2060.671 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2004.6365 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2063.422 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1995.8887 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2095.8958 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2047.585 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2042.5845 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2052.9656 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1968.5127 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1963.0034 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1929.462 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2065.347 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2039.5973 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1898.6853 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1964.1471 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1942.9545 mm
# focal length: (1500, 1500)
# ...
# Root joint depth: 2247.1318 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2194.9226 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2228.1223 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2210.7688 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2224.2507 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2209.4307 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2156.2188 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2135.2715 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2124.0537 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2155.5557 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2131.7788 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2113.2625 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2131.0024 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2005.1494 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2193.2153 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2067.604 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1980.6006 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2019.8918 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2067.9204 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2072.3123 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1914.6809 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1989.7922 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2018.7941 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2026.0925 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1894.6016 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1953.2169 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2209.936 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2057.8745 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2035.3085 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1922.0386 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2062.9277 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2010.5382 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2114.5889 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2229.5962 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2206.6885 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2204.218 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2238.8865 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2260.2058 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2279.4375 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2265.8723 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2265.121 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2245.0554 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2335.2798 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2349.432 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2291.6885 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2296.066 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2300.4397 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2320.6086 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2277.9739 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2284.5542 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2210.5142 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2206.6477 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 1932.954 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2079.1353 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2079.485 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2044.1191 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2228.7935 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2329.6553 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2277.3384 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2335.0696 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2323.9646 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2328.4724 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2333.9338 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2432.6113 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2500.6323 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2618.9436 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2608.5225 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2721.5176 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2748.885 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2610.2703 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2698.3965 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2658.647 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2652.8186 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2699.9543 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2741.3264 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2726.11 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2766.662 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2690.4114 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 2
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2658.837 mm
# Root joint depth: 8787.089 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 2
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2732.4753 mm
# Root joint depth: 7257.034 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2736.2756 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 2
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2700.525 mm
# Root joint depth: 8003.262 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 1
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2644.314 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 2
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 2778.3767 mm
# Root joint depth: 5175.369 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# >>> Using GPU: 0
# >>> Using GPU: 0
# 2
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Root joint depth: 4791.7134 mm
# Root joint depth: 2629.749 mm
# focal length: (1500, 1500)
# principal points: (540.0, 960.0)
# Processed video saved to output_video.mp4
